# %%
import pandas as pd 
import glob
file_path = './Resources_CITY_BIKE_ASSIGNMENT/2023_sample_city_bike_data.csv'

City_bike_data_2023 = pd.read_csv(file_path)
City_bike_data_2023
# Out:
#                 ride_id  rideable_type               started_at  \
# 0      E33ECB69E2EBC53B   classic_bike  2023-11-25 00:26:56.236
# 1      A1579256C79A4043   classic_bike  2023-11-01 21:27:14.982
# 2      0F42A79921482F50  electric_bike  2023-11-19 15:47:08.908
# 3      E1DFFB0490CD9C8A  electric_bike  2023-11-23 07:51:30.614
# 4      7F66C49AC4FAC1D5   classic_bike  2023-11-04 13:28:45.175
# ...                 ...            ...                      ...
# 20033  9CB557AEB02B9627  electric_bike  2023-04-20 10:15:36.692
# 20034  BD6F8A4B43659D1C   classic_bike  2023-04-18 16:35:08.459
# 20035  48DDA05E72FBC28F  electric_bike  2023-04-04 08:47:30.220
# 20036  D7CCB1BA9B74069A  electric_bike  2023-04-06 19:15:28.100
# 20037  44CFBF098896FF7B   classic_bike  2023-04-16 00:08:09.523
#
#                       ended_at          start_station_name start_station_id  \
# 0      2023-11-25 00:33:19.306          E 5 St & Cooper Sq          5712.12
# ...
