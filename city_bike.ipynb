# %%
import pandas as pd

# %%
#reading the data in Pandas
Jan_2022 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202201_Bike_data_sample.csv")

 
Jan_2022
# Out:
#               ride_id  rideable_type               started_at  \
# 0    BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1    7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2    95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3    F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4    7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
# ..                ...            ...                      ...
# 96   36087FEE423BAC05  electric_bike  2022-01-19 12:05:09.925
# 97   1CE4A3035760CA46  electric_bike  2022-01-18 15:51:20.697
# 98   C2DEE105F544943A  electric_bike  2022-01-22 01:47:57.864
# 99   CA62CCA1920AA6A0  electric_bike  2022-01-06 11:57:59.330
# 100  624CACB70B067BA8   classic_bike  2022-01-02 14:45:24.021
#
#                     ended_at         start_station_name  start_station_id  \
# 0    2022-01-21 13:22:31.463    West End Ave & W 107 St           7650.05
# ...

# %%
Feb_2022 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202202_Bike_data_sample.csv")
Feb_2022
# Out:
#               ride_id  rideable_type               started_at  \
# 0    70F3BA79664016C1   classic_bike  2022-02-28 09:22:49.821
# 1    8FA3412A958122D0  electric_bike  2022-02-14 10:47:30.462
# 2    0E2BA02AEAD03EB8  electric_bike  2022-02-18 22:26:55.796
# 3    B626F8E1D7ABABBA   classic_bike  2022-02-09 18:38:18.621
# 4    605E7CC493D08F3B  electric_bike  2022-02-06 14:52:48.564
# ..                ...            ...                      ...
# 96   835ADB5AF70BFFA0   classic_bike  2022-02-09 17:14:48.260
# 97   34335A13A980E73F   classic_bike  2022-02-21 14:42:51.552
# 98   AD0E83944979CBDF  electric_bike  2022-02-16 23:18:50.890
# 99   38B46DF16E72B80D  electric_bike  2022-02-25 16:17:27.368
# 100  0347AB88DCBA87E4   classic_bike  2022-02-19 17:37:16.151
#
#                     ended_at             start_station_name  start_station_id  \
# 0    2022-02-28 09:28:55.174                9 Ave & W 18 St           6190.08
# ...

# %%
March_2022 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202203_Bike_data_sample.csv")
March_2022
# Out:
#               ride_id  rideable_type               started_at  \
# 0    C317818C47CC8335  electric_bike  2022-03-15 07:11:45.401
# 1    B714BEC5DDB33A3E   classic_bike  2022-03-09 18:19:29.764
# 2    4A19425A20ED4392   classic_bike  2022-03-04 07:30:43.751
# 3    F1B2801B596EEB12  electric_bike  2022-03-15 18:53:08.242
# 4    5B32BEC9DF318F17   classic_bike  2022-03-09 18:16:51.579
# ..                ...            ...                      ...
# 96   AB8913A3A33DD967   classic_bike  2022-03-29 18:09:36.257
# 97   0F285B257B892A92   classic_bike  2022-03-19 15:20:06.238
# 98   DDA62050C716D612   classic_bike  2022-03-05 12:39:08.927
# 99   A325C441913F0C86   classic_bike  2022-03-14 18:38:24.945
# 100  204D582EFB564357   classic_bike  2022-03-19 16:42:12.998
#
#                     ended_at        start_station_name  start_station_id  \
# 0    2022-03-15 07:18:41.391           E 91 St & 2 Ave           7286.01
# ...

# %%
Jan_2023 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202301_Bike_data_sample.csv")

 
Jan_2023
# Out:
#               ride_id  rideable_type               started_at  \
# 0    DC1CB984821DFFF7   classic_bike  2023-01-07 15:36:53.430
# 1    C00CA02971557F16   classic_bike  2023-01-04 19:23:01.234
# 2    C753AE5EBD8458F9   classic_bike  2023-01-20 09:22:19.894
# 3    E4415A543C1972A7   classic_bike  2023-01-24 10:38:01.135
# 4    BD52A87B215877C7  electric_bike  2023-01-13 10:17:38.192
# ..                ...            ...                      ...
# 96   D901F513586B4343   classic_bike  2023-01-11 18:36:27.044
# 97   2951E19CAEECFF38   classic_bike  2023-01-24 06:29:25.462
# 98   4380B9383958D605  electric_bike  2023-01-21 13:57:26.159
# 99   BD0C817CA2041A89   classic_bike  2023-01-05 16:05:52.894
# 100  BEF1E1881D062AD4  electric_bike  2023-01-04 16:42:50.821
#
#                     ended_at               start_station_name  \
# 0    2023-01-07 15:39:45.406             Vesey St & Church St
# 1    2023-01-04 19:34:57.151          Lispenard St & Broadway
# ...

# %%
Feb_2023 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202302_Bike_data_sample.csv")

 
Feb_2023
# Out:
#              ride_id  rideable_type               started_at  \
# 0   B354BE3C0834F6BE  electric_bike  2023-02-21 17:20:37.505
# 1   3CCD231D8FABA882  electric_bike  2023-02-02 20:04:50.003
# 2   2EE4EFD27D50719C   classic_bike  2023-02-17 23:31:11.753
# 3   C996B4C8EC1084A0   classic_bike  2023-02-06 06:11:13.144
# 4   421D3470513FF67B   classic_bike  2023-02-22 06:01:46.706
# ..               ...            ...                      ...
# 95  E75113D7EA3DE822   classic_bike  2023-02-18 07:27:31.359
# 96  1F50110C3E2E8660   classic_bike  2023-02-16 12:47:40.661
# 97  88C84FB2B939233D  electric_bike  2023-02-04 15:54:08.597
# 98  2D2A31A948285C45   classic_bike  2023-02-21 19:17:15.030
# 99  8EC9560B6F95ABEE   classic_bike  2023-02-15 10:20:19.874
#
#                    ended_at      start_station_name  start_station_id  \
# 0   2023-02-21 17:23:54.676  St James Pl & Pearl St           5167.06
# 1   2023-02-02 20:27:57.794         E 25 St & 2 Ave           6046.02
# ...

# %%
March_2023 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202303_Bike_data_sample.csv")

 
March_2023
# Out:
#               ride_id  rideable_type               started_at  \
# 0    8F3C1D25816A3B4B  electric_bike  2023-03-20 18:27:11.302
# 1    8336C036E119DBC4  electric_bike  2023-03-11 20:18:13.743
# 2    13C1C610B6B10570   classic_bike  2023-03-03 13:15:16.033
# 3    B150B04D4A0991A6  electric_bike  2023-03-04 12:43:53.958
# 4    0F4F4D7B6B95CC23  electric_bike  2023-03-04 17:36:44.714
# ..                ...            ...                      ...
# 96   85BEDD1AE908A872  electric_bike  2023-03-14 13:49:29.217
# 97   480A27080414D268   classic_bike  2023-03-18 02:51:44.049
# 98   9D9BBD6D6596E089   classic_bike  2023-03-24 20:19:56.963
# 99   1B76FDAC91E3A152  electric_bike  2023-03-18 08:28:44.066
# 100  A93C7413B89E63BB   classic_bike  2023-03-11 11:40:12.868
#
#                     ended_at          start_station_name  start_station_id  \
# 0    2023-03-20 18:43:42.261          S 4 St & Wythe Ave           5204.05
# ...

# %%
Jan_2024 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202401_Bike_data_sample.csv")

 
Jan_2024
# Out:
#              ride_id  rideable_type               started_at  \
# 0   5078F3D302000BD2  electric_bike  2024-01-22 18:43:19.012
# 1   814337105D37302A  electric_bike  2024-01-11 19:19:18.721
# 2   A33A920E2B10710C  electric_bike  2024-01-30 19:17:41.693
# 3   A3A5FC0DD7D34D74  electric_bike  2024-01-27 11:27:01.759
# 4   6F96728ECEFBDAA4  electric_bike  2024-01-16 15:15:41.000
# ..               ...            ...                      ...
# 95  0C3167B2B789FD78   classic_bike  2024-01-29 09:26:22.781
# 96  E585D6178E2B5656  electric_bike  2024-01-17 16:12:34.955
# 97  663417F7D83ED71E  electric_bike  2024-01-10 09:53:40.174
# 98  863AEEB9A5A55F1F  electric_bike  2024-01-10 08:00:37.249
# 99  BE4DBC056A3F1890  electric_bike  2024-01-31 17:47:29.224
#
#                    ended_at                  start_station_name  \
# 0   2024-01-22 18:48:10.708  Frederick Douglass Blvd & W 145 St
# 1   2024-01-11 19:47:36.007                     W 54 St & 6 Ave
# ...

# %%
Feb_2024 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202402_Bike_data_sample.csv")

 
Feb_2024
# Out:
#              ride_id  rideable_type               started_at  \
# 0   B2B980E0EAE1D6F1   classic_bike  2024-02-25 20:25:40.894
# 1   1069DDA1FED20568   classic_bike  2024-02-21 22:21:38.446
# 2   B58850AF6F2D8BD5  electric_bike  2024-02-14 08:31:14.609
# 3   D46E6C5A69048E11  electric_bike  2024-02-05 08:42:25.999
# 4   707AF4CF2C7834C2  electric_bike  2024-02-08 11:13:15.969
# ..               ...            ...                      ...
# 95  52C917A049A23344  electric_bike  2024-02-02 18:51:52.549
# 96  06F8FE76F5D53A84   classic_bike  2024-02-11 13:34:56.537
# 97  0D6C7E26821D88C2   classic_bike  2024-02-10 12:35:36.104
# 98  E691A05059588539  electric_bike  2024-02-20 18:41:57.983
# 99  86FB7EFC30834290   classic_bike  2024-02-16 15:57:19.233
#
#                    ended_at        start_station_name  start_station_id  \
# 0   2024-02-25 20:43:58.504  Greenwich St & Hubert St           5470.10
# 1   2024-02-21 22:40:12.259  Greenwich St & Hubert St           5470.10
# ...

# %%
March_2024 = pd.read_csv("../Resources_CITY_BIKE_ASSIGNMENT/202403_Bike_data_sample.csv")

 
March_2024
# Out:
#              ride_id  rideable_type               started_at  \
# 0   62021B31AF42943E  electric_bike  2024-03-13 15:57:41.800
# 1   EC7BE9D296FFD072  electric_bike  2024-03-16 10:25:46.114
# 2   EC85C0EEC95157BB   classic_bike  2024-03-20 19:20:49.818
# 3   9DDE9AF5606B4E0F   classic_bike  2024-03-13 20:31:12.599
# 4   E4446F457328C5FE  electric_bike  2024-03-16 10:50:11.535
# ..               ...            ...                      ...
# 95  7BF592BACE949C47  electric_bike  2024-03-27 17:22:27.888
# 96  D0D7DDB5AF22ACC7  electric_bike  2024-03-07 10:50:41.689
# 97  62B43342A1537488  electric_bike  2024-03-07 13:03:37.191
# 98  6892CE6CC1FD1248   classic_bike  2024-03-21 15:05:23.338
# 99  6D0FBEB0F474549A   classic_bike  2024-03-17 12:14:47.971
#
#                    ended_at                   start_station_name  \
# 0   2024-03-13 16:07:09.853                Forsyth St & Grand St
# 1   2024-03-16 10:30:21.554                      E 12 St & 3 Ave
# ...

# %%
# Create a list of your dataframes
dfs= [Jan_2022,Feb_2022,March_2022,Jan_2023,Feb_2023,March_2023,Jan_2024,Feb_2024,March_2024]

# Concatenate them
city_bike_data_2022_to_2024 = pd.concat(dfs)


# If you want to reset the index after merging 
city_bike_data_2022_to_2024.reset_index(drop=True, inplace=True)

city_bike_data_2022_to_2024
# Out:
#               ride_id  rideable_type               started_at  \
# 0    BFD29218AB271154  electric_bike  2022-01-21 13:13:43.392
# 1    7C953F2FD7BE1302   classic_bike  2022-01-10 11:30:54.162
# 2    95893ABD40CED4B8  electric_bike  2022-01-26 10:52:43.096
# 3    F853B50772137378   classic_bike  2022-01-03 08:35:48.247
# 4    7590ADF834797B4B   classic_bike  2022-01-22 14:14:23.043
# ..                ...            ...                      ...
# 900  7BF592BACE949C47  electric_bike  2024-03-27 17:22:27.888
# 901  D0D7DDB5AF22ACC7  electric_bike  2024-03-07 10:50:41.689
# 902  62B43342A1537488  electric_bike  2024-03-07 13:03:37.191
# 903  6892CE6CC1FD1248   classic_bike  2024-03-21 15:05:23.338
# 904  6D0FBEB0F474549A   classic_bike  2024-03-17 12:14:47.971
#
#                     ended_at                   start_station_name  \
# 0    2022-01-21 13:22:31.463              West End Ave & W 107 St
# 1    2022-01-10 11:41:43.422                         4 Ave & 3 St
# ...

# %%
# saving the data in csv
city_bike_data_2022_to_2024.to_csv('city_bike_data_2022_to_2024.csv', index=False)

# %% [markdown]
# ** # Efficient way to combining multiple csv files

# %%
import pandas as pd 
import glob
file_path = './Resources_CITY_BIKE_ASSIGNMENT/*.csv'
csv_files = glob.glob(file_path)

# %%
df_list = [pd.read_csv(file) for file in csv_files] 
combined_df = pd.concat(df_list, ignore_index=True)

# %%
# Convert the columns to datetime 
combined_df['started_at'] = pd.to_datetime(combined_df['started_at']) 
combined_df['ended_at'] = pd.to_datetime(combined_df['ended_at'])

# Extract year and time 
combined_df['year'] = combined_df['started_at'].dt.year 
combined_df['start_time'] = combined_df['started_at'].dt.time 
combined_df['end_time'] = combined_df['ended_at'].dt.time

#Format the time to show two decimal places for seconds 
combined_df['start_time'] = combined_df['started_at'].dt.strftime('%H:%M:%S.%f').str[:-4] 
combined_df['end_time'] = combined_df['ended_at'].dt.strftime('%H:%M:%S.%f').str[:-4]


combined_df
# Out:
#               ride_id  rideable_type              started_at  \
# 0    DC1CB984821DFFF7   classic_bike 2023-01-07 15:36:53.430
# 1    C00CA02971557F16   classic_bike 2023-01-04 19:23:01.234
# 2    C753AE5EBD8458F9   classic_bike 2023-01-20 09:22:19.894
# 3    E4415A543C1972A7   classic_bike 2023-01-24 10:38:01.135
# 4    BD52A87B215877C7  electric_bike 2023-01-13 10:17:38.192
# ..                ...            ...                     ...
# 900  AB8913A3A33DD967   classic_bike 2022-03-29 18:09:36.257
# 901  0F285B257B892A92   classic_bike 2022-03-19 15:20:06.238
# 902  DDA62050C716D612   classic_bike 2022-03-05 12:39:08.927
# 903  A325C441913F0C86   classic_bike 2022-03-14 18:38:24.945
# 904  204D582EFB564357   classic_bike 2022-03-19 16:42:12.998
#
#                    ended_at        start_station_name  start_station_id  \
# 0   2023-01-07 15:39:45.406      Vesey St & Church St           5216.06
# 1   2023-01-04 19:34:57.151   Lispenard St & Broadway           5391.06
# ...

# %%
#dropping the unwanted columns 
combined_df = combined_df.drop(columns=['started_at','ended_at'])

combined_df
# Out:
#               ride_id  rideable_type        start_station_name  \
# 0    DC1CB984821DFFF7   classic_bike      Vesey St & Church St
# 1    C00CA02971557F16   classic_bike   Lispenard St & Broadway
# 2    C753AE5EBD8458F9   classic_bike   3 Ave & Schermerhorn St
# 3    E4415A543C1972A7   classic_bike            E 5 St & Ave A
# 4    BD52A87B215877C7  electric_bike          W 54 St & 11 Ave
# ..                ...            ...                       ...
# 900  AB8913A3A33DD967   classic_bike           E 16 St & 5 Ave
# 901  0F285B257B892A92   classic_bike           E 16 St & 5 Ave
# 902  DDA62050C716D612   classic_bike      S 3 St & Bedford Ave
# 903  A325C441913F0C86   classic_bike       Washington Square E
# 904  204D582EFB564357   classic_bike  Congress St & Clinton St
#
#      start_station_id               end_station_name  end_station_id  \
# 0             5216.06       Albany St & Greenwich St         5145.02
# ...

# %%
combined_df.to_csv('city_bike_data_2022_to_2024.csv', index=False)
